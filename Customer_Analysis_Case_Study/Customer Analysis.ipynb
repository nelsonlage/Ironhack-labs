# %% [markdown]
# # Lab Case Study
# ___
#
# ## Scenario
# ___
# You are working as an analyst for an auto insurance company. The company has collected some data about its customers including their demographics, education, employment, policy details, vehicle information on which insurance policy is, and claim amounts. You will help the senior management with some business questions that will help them to better understand their customers, improve their services, and improve profitability.
#
#
# ## Business Objectives
# ---
# - Retain customers,
# - analyze relevant customer data,
# - develop focused customer retention programs.
#
# Based on the analysis, take targeted actions to increase profitable customer response, retention, and growth.
#
# ## Activities
# ___
# - [ ] Aggregate data into one Data Frame using Pandas.
# - [ ] Standardizing header names
# - [ ] Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data
# - [ ] Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of complaints )
# - [ ] Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns
# - [ ] Removing duplicates
# - [ ] Replacing null values – Replace missing values with means of the column (for numerical columns)
#
# ## Data
# ___
# The csv files is provided in the folder. The columns in the file are self-explanatory.

# %% [markdown]
# ###  Importing relevant libraries / modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Importing and merging files

# %%
file1 = pd.read_csv('Data/file1.csv')
file2 = pd.read_csv('Data/file2.csv')
file3 = pd.read_csv('Data/file3.csv')

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
file1.dropna(axis=0, how='all')
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 1066              305955.03%  38644.0                  78.0
# 1067             2031499.76%  63209.0                 102.0
# 1068              323912.47%  16061.0                  88.0
# 1069              462680.11%  79487.0                 114.0
# 1070              899704.02%  54230.0                 112.0
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 1066                    1/1/00   Personal Auto  Four-Door Car
# 1067                    1/2/00   Personal Auto            SUV
# 1068                    1/0/00   Personal Auto  Four-Door Car
# 1069                    1/0/00    Special Auto            SUV
# 1070                    1/0/00   Personal Auto   Two-Door Car
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 1066          361.455219
# 1067          207.320041
# 1068          633.600000
# 1069          547.200000
# 1070          537.600000
#
# [1071 rows x 11 columns]

# %%
file1.dropna(axis=0, how='all')
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 1066              305955.03%  38644.0                  78.0
# 1067             2031499.76%  63209.0                 102.0
# 1068              323912.47%  16061.0                  88.0
# 1069              462680.11%  79487.0                 114.0
# 1070              899704.02%  54230.0                 112.0
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 1066                    1/1/00   Personal Auto  Four-Door Car
# 1067                    1/2/00   Personal Auto            SUV
# 1068                    1/0/00   Personal Auto  Four-Door Car
# 1069                    1/0/00    Special Auto            SUV
# 1070                    1/0/00   Personal Auto   Two-Door Car
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 1066          361.455219
# 1067          207.320041
# 1068          633.600000
# 1069          547.200000
# 1070          537.600000
#
# [1071 rows x 11 columns]

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# 0         M       0                   104                          0
# 1         M       0                    66                          0
# 2         F   25820                    82                          0
# 3         F       0                   121                          0
# 4         M   30366                   101                          2
# ...     ...     ...                   ...                        ...
# 7065      M   71941                    73                          0
# 7066      F   21604                    79                          0
# 7067      M       0                    85                          3
# 7068      M   21941                    96                          0
# 7069      M       0                    77                          0
#
#          Policy Type  Total Claim Amount  Vehicle Class
# 0      Personal Auto          499.200000   Two-Door Car
# 1      Personal Auto            3.468912   Two-Door Car
# 2      Personal Auto          393.600000  Four-Door Car
# 3      Personal Auto          699.615192            SUV
# 4      Personal Auto          484.800000            SUV
# ...              ...                 ...            ...
# 7065   Personal Auto          198.234764  Four-Door Car
# 7066  Corporate Auto          379.200000  Four-Door Car
# 7067  Corporate Auto          790.784983  Four-Door Car
# 7068   Personal Auto          691.200000  Four-Door Car
# 7069  Corporate Auto          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %%
df = pd.concat([file1, file2, file3]).reset_index(drop=True)
df
# Out:
#       Customer          ST GENDER             Education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316         NaN    NaN              Bachelor
# 12070  PK87824         NaN    NaN               College
# 12071  TD14365         NaN    NaN              Bachelor
# 12072  UP19263         NaN    NaN               College
# 12073  Y167826         NaN    NaN               College
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# 3                  764586.18%      0.0                 106.0
# 4                  536307.65%  36357.0                  68.0
# ...                       ...      ...                   ...
# 12069             23405.98798  71941.0                  73.0
# 12070             3096.511217  21604.0                  79.0
# 12071             8163.890428      0.0                  85.0
# 12072             7524.442436  21941.0                  96.0
# 12073             2611.836866      0.0                  77.0
#
#       Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                        1/0/00   Personal Auto  Four-Door Car
# 1                        1/0/00   Personal Auto  Four-Door Car
# 2                        1/0/00   Personal Auto   Two-Door Car
# 3                        1/0/00  Corporate Auto            SUV
# 4                        1/0/00   Personal Auto  Four-Door Car
# ...                         ...             ...            ...
# 12069                         0   Personal Auto  Four-Door Car
# 12070                         0  Corporate Auto  Four-Door Car
# 12071                         3  Corporate Auto  Four-Door Car
# 12072                         0   Personal Auto  Four-Door Car
# 12073                         0  Corporate Auto   Two-Door Car
#
#        Total Claim Amount       State Gender
# 0                2.704934         NaN    NaN
# 1             1131.464935         NaN    NaN
# 2              566.472247         NaN    NaN
# 3              529.881344         NaN    NaN
# 4               17.269323         NaN    NaN
# ...                   ...         ...    ...
# 12069          198.234764  California      M
# 12070          379.200000  California      F
# 12071          790.784983  California      M
# 12072          691.200000  California      M
# 12073          369.600000  California      M
#
# [12074 rows x 13 columns]

# %% [markdown]
# Some observations about the data:
# - There are two columns for state ('ST' and State') and two columns for gender ('GENDER', 'Gender')
#     - That's due to 'file3' having a different structure compared to files 1 and 2.
# - The column 'Customer Lifetime Value' has inconsistent values (some are missing the '%' symbol)
# - The column 'Number of Open Complaints' also has inconsistent values
# - For analysis purposes, the 'Customer' column doesn't add any useful information

# %% [markdown]
# ### Standardizing header names

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
df
# Out:
#       customer          st gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316         NaN    NaN              Bachelor
# 12070  PK87824         NaN    NaN               College
# 12071  TD14365         NaN    NaN              Bachelor
# 12072  UP19263         NaN    NaN               College
# 12073  Y167826         NaN    NaN               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# 3                  764586.18%      0.0                 106.0
# 4                  536307.65%  36357.0                  68.0
# ...                       ...      ...                   ...
# 12069             23405.98798  71941.0                  73.0
# 12070             3096.511217  21604.0                  79.0
# 12071             8163.890428      0.0                  85.0
# 12072             7524.442436  21941.0                  96.0
# 12073             2611.836866      0.0                  77.0
#
#       number_of_open_complaints     policy_type  vehicle_class  \
# 0                        1/0/00   Personal Auto  Four-Door Car
# 1                        1/0/00   Personal Auto  Four-Door Car
# 2                        1/0/00   Personal Auto   Two-Door Car
# 3                        1/0/00  Corporate Auto            SUV
# 4                        1/0/00   Personal Auto  Four-Door Car
# ...                         ...             ...            ...
# 12069                         0   Personal Auto  Four-Door Car
# 12070                         0  Corporate Auto  Four-Door Car
# 12071                         3  Corporate Auto  Four-Door Car
# 12072                         0   Personal Auto  Four-Door Car
# 12073                         0  Corporate Auto   Two-Door Car
#
#        total_claim_amount       state gender
# 0                2.704934         NaN    NaN
# 1             1131.464935         NaN    NaN
# 2              566.472247         NaN    NaN
# 3              529.881344         NaN    NaN
# 4               17.269323         NaN    NaN
# ...                   ...         ...    ...
# 12069          198.234764  California      M
# 12070          379.200000  California      F
# 12071          790.784983  California      M
# 12072          691.200000  California      M
# 12073          369.600000  California      M
#
# [12074 rows x 13 columns]

# %% [markdown]
# ### Deleting unecessary columns

# %%
df.drop('customer', axis=1, inplace=True)

# %%
df
# Out:
#                st gender             education customer_lifetime_value  \
# 0      Washington    NaN                Master                     NaN
# 1         Arizona      F              Bachelor              697953.59%
# 2          Nevada      F              Bachelor             1288743.17%
# 3      California      M              Bachelor              764586.18%
# 4      Washington      M  High School or Below              536307.65%
# ...           ...    ...                   ...                     ...
# 12069         NaN    NaN              Bachelor             23405.98798
# 12070         NaN    NaN               College             3096.511217
# 12071         NaN    NaN              Bachelor             8163.890428
# 12072         NaN    NaN               College             7524.442436
# 12073         NaN    NaN               College             2611.836866
#
#         income  monthly_premium_auto number_of_open_complaints  \
# 0          0.0                1000.0                    1/0/00
# 1          0.0                  94.0                    1/0/00
# 2      48767.0                 108.0                    1/0/00
# 3          0.0                 106.0                    1/0/00
# 4      36357.0                  68.0                    1/0/00
# ...        ...                   ...                       ...
# 12069  71941.0                  73.0                         0
# 12070  21604.0                  79.0                         0
# 12071      0.0                  85.0                         3
# 12072  21941.0                  96.0                         0
# 12073      0.0                  77.0                         0
#
#           policy_type  vehicle_class  total_claim_amount       state gender
# 0       Personal Auto  Four-Door Car            2.704934         NaN    NaN
# 1       Personal Auto  Four-Door Car         1131.464935         NaN    NaN
# 2       Personal Auto   Two-Door Car          566.472247         NaN    NaN
# 3      Corporate Auto            SUV          529.881344         NaN    NaN
# 4       Personal Auto  Four-Door Car           17.269323         NaN    NaN
# ...               ...            ...                 ...         ...    ...
# 12069   Personal Auto  Four-Door Car          198.234764  California      M
# 12070  Corporate Auto  Four-Door Car          379.200000  California      F
# 12071  Corporate Auto  Four-Door Car          790.784983  California      M
# 12072   Personal Auto  Four-Door Car          691.200000  California      M
# 12073  Corporate Auto   Two-Door Car          369.600000  California      M
#
# [12074 rows x 12 columns]

# %% [markdown]
# ### Filtering data and correcting typos

# %% [markdown]
# #### 'st' vc 'state'

# %%
df['st'].value_counts(dropna=False)
# Out:
# NaN           10007
# Oregon          623
# California      488
# Arizona         328
# Nevada          223
# Washington      181
# Cali            120
# AZ               74
# WA               30
# Name: st, dtype: int64

# %%
df['state'].value_counts(dropna=False)
# Out:
# NaN           5004
# California    2544
# Oregon        1978
# Arizona       1302
# Nevada         659
# Washington     587
# Name: state, dtype: int64

# %% [markdown]
# First, let's starndardize the names in column 'st'. Then we're going to use 'state' to replace some null values that are caused by the way the files were concatenated.

# %%
df['st'] = df['st'].replace({'Cali': 'California', 'AZ': 'Arizona', 'WA': 'Washington'})

# %%
df['st'] = df['st'].fillna(df['state'])
df['st'].value_counts(dropna=False)
# Out:
# California    3152
# NaN           2937
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: st, dtype: int64

# %% [markdown]
# Now, all our information about the states are condensed in the column 'st'. We can rename it and get rid of the second column.

# %%
df.drop('state', axis=1, inplace=True)

# %%
df.rename(columns={'st': 'state'}, inplace=True)
df
# Out:
#             state gender             education customer_lifetime_value  \
# 0      Washington    NaN                Master                     NaN
# 1         Arizona      F              Bachelor              697953.59%
# 2          Nevada      F              Bachelor             1288743.17%
# 3      California      M              Bachelor              764586.18%
# 4      Washington      M  High School or Below              536307.65%
# ...           ...    ...                   ...                     ...
# 12069  California    NaN              Bachelor             23405.98798
# 12070  California    NaN               College             3096.511217
# 12071  California    NaN              Bachelor             8163.890428
# 12072  California    NaN               College             7524.442436
# 12073  California    NaN               College             2611.836866
#
#         income  monthly_premium_auto number_of_open_complaints  \
# 0          0.0                1000.0                    1/0/00
# 1          0.0                  94.0                    1/0/00
# 2      48767.0                 108.0                    1/0/00
# 3          0.0                 106.0                    1/0/00
# 4      36357.0                  68.0                    1/0/00
# ...        ...                   ...                       ...
# 12069  71941.0                  73.0                         0
# 12070  21604.0                  79.0                         0
# 12071      0.0                  85.0                         3
# 12072  21941.0                  96.0                         0
# 12073      0.0                  77.0                         0
#
#           policy_type  vehicle_class  total_claim_amount gender
# 0       Personal Auto  Four-Door Car            2.704934    NaN
# 1       Personal Auto  Four-Door Car         1131.464935    NaN
# 2       Personal Auto   Two-Door Car          566.472247    NaN
# 3      Corporate Auto            SUV          529.881344    NaN
# 4       Personal Auto  Four-Door Car           17.269323    NaN
# ...               ...            ...                 ...    ...
# 12069   Personal Auto  Four-Door Car          198.234764      M
# 12070  Corporate Auto  Four-Door Car          379.200000      F
# 12071  Corporate Auto  Four-Door Car          790.784983      M
# 12072   Personal Auto  Four-Door Car          691.200000      M
# 12073  Corporate Auto   Two-Door Car          369.600000      M
#
# [12074 rows x 11 columns]

# %% [markdown]
# #### 'gender'

# %%
# only posible with indices, as there are two columns with the same name!
df.iloc[:, 1].value_counts(dropna=False)
# Out:
# NaN       10129
# F           984
# M           874
# Male         40
# female       30
# Femal        17
# Name: gender, dtype: int64

# %%
df.iloc[:, 10].value_counts(dropna=False)
# Out:
# NaN    5004
# F      3576
# M      3494
# Name: gender, dtype: int64

# %% [markdown]
# First, let's starndardize the values in the first 'gender' column (index 1). Then we're going to use the values from the second column (index 10) to replace some null values that are caused by the way the files were concatenated.

# %%
df.iloc[:, 1] = df.iloc[:, 1].replace('Male', 'M').replace(['female', 'Femal'], 'F')
df.iloc[:, 1].value_counts(dropna=False)
# Out:
# NaN    10129
# F       1031
# M        914
# Name: gender, dtype: int64

# %%
df.iloc[:, 1] = df.iloc[:, 1].fillna(df.iloc[:, 10])
df.iloc[:, 1].value_counts(dropna=False)
# Out:
# F      4607
# M      4408
# NaN    3059
# Name: gender, dtype: int64

# %% [markdown]
# Now, all our information about the states are condensed in one column ('gender', index 1) and we can get rid of the second column (index 10).

# %%
df.drop(df.columns[10], axis=1, inplace=True)

# %%
df
# Out:
#             state             education customer_lifetime_value   income  \
# 0      Washington                Master                     NaN      0.0
# 1         Arizona              Bachelor              697953.59%      0.0
# 2          Nevada              Bachelor             1288743.17%  48767.0
# 3      California              Bachelor              764586.18%      0.0
# 4      Washington  High School or Below              536307.65%  36357.0
# ...           ...                   ...                     ...      ...
# 12069  California              Bachelor             23405.98798  71941.0
# 12070  California               College             3096.511217  21604.0
# 12071  California              Bachelor             8163.890428      0.0
# 12072  California               College             7524.442436  21941.0
# 12073  California               College             2611.836866      0.0
#
#        monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                    1000.0                    1/0/00   Personal Auto
# 1                      94.0                    1/0/00   Personal Auto
# 2                     108.0                    1/0/00   Personal Auto
# 3                     106.0                    1/0/00  Corporate Auto
# 4                      68.0                    1/0/00   Personal Auto
# ...                     ...                       ...             ...
# 12069                  73.0                         0   Personal Auto
# 12070                  79.0                         0  Corporate Auto
# 12071                  85.0                         3  Corporate Auto
# 12072                  96.0                         0   Personal Auto
# 12073                  77.0                         0  Corporate Auto
#
#        vehicle_class  total_claim_amount
# 0      Four-Door Car            2.704934
# 1      Four-Door Car         1131.464935
# 2       Two-Door Car          566.472247
# 3                SUV          529.881344
# 4      Four-Door Car           17.269323
# ...              ...                 ...
# 12069  Four-Door Car          198.234764
# 12070  Four-Door Car          379.200000
# 12071  Four-Door Car          790.784983
# 12072  Four-Door Car          691.200000
# 12073   Two-Door Car          369.600000
#
# [12074 rows x 9 columns]

# %% [markdown]
# ### Checking and correcting data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   education                  9137 non-null   object
#  2   customer_lifetime_value    9130 non-null   object
#  3   income                     9137 non-null   float64
#  4   monthly_premium_auto       9137 non-null   float64
#  5   number_of_open_complaints  9137 non-null   object
#  6   policy_type                9137 non-null   object
#  7   vehicle_class              9137 non-null   object
#  8   total_claim_amount         9137 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 849.1+ KB

# %% [markdown]
# One should expect the columns 'customer_lifetime_value' and 'number_of_open_complaints'. Let's investigate these columns.

# %%
df['number_of_open_complaints'].value_counts(dropna=False)  ## get the middle number
# Out:
# 0         5629
# NaN       2937
# 1/0/00    1626
# 1          765
# 2          283
# 1/1/00     247
# 3          230
# 4          119
# 1/2/00      93
# 1/3/00      60
# 5           44
# 1/4/00      29
# 1/5/00      12
# Name: number_of_open_complaints, dtype: int64

# %%
df['number_of_open_complaints'].str.contains('/').sum()
# Out:
# 2067

# %%
# check if string has anything that is not a number
df['customer_lifetime_value'].str.contains('(?!^\d+$)^.+$').sum()
# Out:
# 2060

# %%
df['customer_lifetime_value'].str.contains('%').sum()
# Out:
# 2060

# %% [markdown]
# The only character that is not a number is the '%'. So let's replace it and convert the values.

# %%
df['customer_lifetime_value'].str.replace('%', '').astype(float)
# Out:
# 0               NaN
# 1         697953.59
# 2        1288743.17
# 3         764586.18
# 4         536307.65
#             ...
# 12069           NaN
# 12070           NaN
# 12071           NaN
# 12072           NaN
# 12073           NaN
# Name: customer_lifetime_value, Length: 12074, dtype: float64

# %%
str1 = '1/1/00'

int(str1.split('/')[1])
# Out:
# 1

# %%
'/' in np.nan
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-da2cbba8baf2> in <module>
# ----> 1 '/' in np.nan
#
# TypeError: argument of type 'float' is not iterable
