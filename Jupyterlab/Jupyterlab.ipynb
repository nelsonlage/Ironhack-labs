# %% [markdown]
# # Holiday preferences

# %% [markdown]
# This exercise is part of the Ironhack Data Analysis bootcamp (OCT2021). The goal is to become familiar with some Jupyter notebook features, especially markdown formatting. In this notebook, I'll introduce my holiday preferences.

# %% [markdown]
# ## Content
# 1. [Libraries and modules](#Import-relevant-libraries-/-modules)
# 2. [Choose a person](#Choose-a-person)
# 3. [A nice picture](#Choose-a-picture-of-the-person)
# 4. [Holiday preferences](#Holiday-preferences)
# 5. [Picture of the place](#Choose-a-picture-of-the-place)
# 6. [Things to do](#Things-to-do)
# 7. [Video](#Video-from-the-place)

# %% [markdown]
# ## Import relevant libraries / modules

# %%
# This module is necessary to play videos from youtube

from IPython.display import YouTubeVideo

# %% [markdown]
# ## Choose a person

# %%
def users_name():
    
    '''
    Ask user to enter a name
    '''
    
    print("Please enter a name: ")
    user_name = input()

# %%
users_name()
# Out:
# Please enter a name:
# Nelson

# %% [markdown]
# ## Choose a picture of this person

# %% [markdown]
# ![image001.jpg](attachment:image001.jpg)

# %% [markdown]
# ## Holiday preferences

# %%
def users_preferences():
    
    '''
    Ask questions about someone's holiday preferences
    '''
    
    print('What\'s your favorite destination?')
    question_1 = input()
    
    print('\nHow far is it from your homeland?')
    question_2 = input()
    
    print('\nWould like to go back there?')
    question_3 = input()

# %%
users_preferences()
# Out:
# What's your favorite destination?
# Budapest
#
# How far is it from your homeland?
# Almost 10000 km!
#
# Would like to go back there?
# Definitely!

# %% [markdown]
# ## Choose a picture of the place

# %% [markdown]
# ![budapest.jpg](attachment:budapest.jpg)

# %% [markdown]
# ## Things to do

# %% [markdown]
# - **Parlament building**: one of the most impressive buildings in Europe
# - **River cruises**: in the evening, you can see most of Budapest landmarks with an amazing lighting
# - **Ruin pubs**: these picturesque places are super fun and unique

# %% [markdown]
# ## Video from the place

# %%
YouTubeVideo(id='B_Hfmp-z7AE')
