# %% [markdown]
# # Holiday preferences

# %% [markdown]
# This exercise is part of the Ironhack Data Analysis bootcamp (OCT2021). The goal is to become familiar with some Jupyter notebook features, especially regarding markdown. In this notebook I'll introduce my holiday preferences.

# %% [markdown]
# ## Content
# 1. [Libraries](#Import-relevant-libraries)
# 2. [The main character](#Who-are-you?)
# 3. [Picture](#Choose-a-picture-of-you)
# 4. [Preferences](#Preferences)
# 5. [Picture](#Choose-a-picture-of-the-place)
# 6. [Things to do](#Things-to-do)
# 7. [Video](#Video)

# %% [markdown]
# ## Import relevant libraries

# %%
# This module is necessary to play videos

from IPython.display import IFrame

# %% [markdown]
# ## Who are you?

# %%
def users_name():
    
    '''
    Asks user for an input (his name)
    '''
    
    print("Please enter a name: ")
    user_name = input()

# %%
users_name()
# Out:
# Please enter a name:
# Nelson

# %% [markdown]
# ## Choose a picture of you

# %% [markdown]
# <img src="DSC07118.JPG" style="width: 200;"/>

# %% [markdown]
# ## Preferences

# %%
def users_preferences():
    
    '''
    Ask users for input on its holiday preferences
    '''
    
    print('What\'s your favorite destination?')
    question_1 = input()
    
    print('\nHow far is it from your homeland?')
    question_2 = input()
    
    print('\nWould like to go back there?')
    question_3 = input()

# %%
users_preferences()
# Out:
# What's your favorite destination?
# Budapest
#
# How far is it from your homeland?
# Pretty far (close to 10000 km!)
#
# Would like to go back there?
# Yes, definetely!

# %% [markdown]
# ## Choose a picture of the place

# %% [markdown]
# ![budapest.jpg](attachment:budapest.jpg)

# %% [markdown]
# ## Things to do

# %% [markdown]
# - Parlament building
# - River cruises
# - Ruin pubs

# %% [markdown]
# ## Video

# %%
IFrame('https://www.youtube.com/watch?v=B_Hfmp-z7AE', '500', '100')
# Out:
#         <iframe
#             width="500"
#             height="100"
#             src="https://www.youtube.com/watch?v=B_Hfmp-z7AE"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
